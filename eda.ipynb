# %%
import pandas as pd

# %%
data = pd.read_csv('./data.csv')
data.head()
# Out:
#                         Project  Project Type            Lead Agency  \
# 0       Washington Union Station      Transit           FRA/ Amtrak
# 1                    Long Bridge       Bridge                   VDOT
# 2         DC Second Water Source        Water  US Army, DOI, Defense
# 3   Universal Broadband Citywide   Technology                   OCTO
# 4  South Capitol Street Corridor      Primary                   DDOT
#
#           Cost  Completion Year Engineering Status Construction Status  \
# 0  $8.7 Billion            FY32        In Progress        Not Started
# 1  $1.9 Billion          FY2026           Complete                 NaN
# 2             ?          FY2030        Not started         Not Started
# 3    $5,419,000          FY2026        In Progress         Not Started
# 4  $555,000,000          FY2025           Complete       Construciton
#
#     Permitting Status               Funding Status  Jobs Created  \
# ...

# %%
data['Project Type'].value_counts()
# Out:
# Water         10
# Bridge         3
# Transit        3
# Primary        2
# Maitenance     2
# Technology     1
# Intersate      1
# Transit        1
# Name: Project Type, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Project              23 non-null     object
#  1   Project Type         23 non-null     object
#  2   Lead Agency          23 non-null     object
#  3   Cost                 23 non-null     object
#  4   Completion Year      11 non-null     object
#  5   Engineering Status   19 non-null     object
#  6   Construction Status  16 non-null     object
#  7   Permitting Status    15 non-null     object
#  8   Funding Status       6 non-null      object
#  9   Jobs Created         1 non-null      object
#  10  Description          17 non-null     object
# dtypes: object(11)
# memory usage: 2.1+ KB

# %%
data.columns = data.columns.str.strip(' ')

# %%
def clean_billions(text):
    if 'Billion' in text:
        text = text.strip(' Billion')
        text = text.replace('.', ',')
        text += '00,000,000'
    return text
def clean_numeric(text):
    new_text = clean_billions(text)
    new_text = new_text.replace(',', '')
    return new_text
clean_text(data['Cost'].head(1).values[0])
# Out:
# '$8700000000'

# %%
data['Cost'] = data['Cost'].str.strip('$').replace('?', '0')

data['Cost'] = data.Cost.apply(clean_text).astype('float')

data
# Out:
#                                               Project Project Type  \
# 0                            Washington Union Station      Transit
# 1                                         Long Bridge       Bridge
# 2                              DC Second Water Source        Water
# 3                        Universal Broadband Citywide   Technology
# 4                       South Capitol Street Corridor      Primary
# 5            Theodore Roosevelt Bridge Rehabilitation   Maitenance
# 6                 11th Street Bridge SE Replacement\r    Intersate
# 7                             11th Street Bridge Park       Bridge
# 8     St. Elizabeth's East Capmus Access Improvements      Primary
# 9   Benning Road Reconstruction + Streetcar Extension     Transit
# 10                                   K St. Transitway     Transit
# 11                                        H St Bridge       Bridge
# 12                        Bus Efficiency Enhancements     Transit
# ...
