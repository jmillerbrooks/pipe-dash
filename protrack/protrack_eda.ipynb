# %%
import pandas as pd
import matplotlib as plt

# %%
init_line_df = pd.read_csv('./ProTrack_Project_Initiation_Line.csv')

init_line_df.columns
# Out:
# Index(['OBJECTID', 'GLOBALID', 'PIID', 'PIIDBI', 'UNIQUEID', 'PROJECTNAME',
#        'WORKTYPE', 'DESCRIPTION', 'COMMENTS', 'ROUTENAME', 'FROMSTREET',
#        'TOSTREET', 'ROUTEID', 'FROMMEASURE', 'TOMEASURE', 'MILES',
#        'FUNCTIONALCLASS', 'ESTIMATEDSTARTDATE', 'ESTIMATEDCOMPLETIONDATE',
#        'ESTIMATEDCOST', 'CONDITION', 'WARD', 'ISNHS', 'SIDE', 'BUDGETYEAR',
#        'PROJECTIDENTIFIER', 'CREATEDDATE', 'LASTUPDATEDDATE', 'ISSELECTED',
#        'SMD', 'ANC', 'STATUS', 'SHAPELEN'],
#       dtype='object')

# %%
init_line_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7715 entries, 0 to 7714
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   OBJECTID                 7715 non-null   int64
#  1   GLOBALID                 7715 non-null   object
#  2   PIID                     7715 non-null   int64
#  3   PIIDBI                   7715 non-null   object
#  4   UNIQUEID                 7715 non-null   int64
#  5   PROJECTNAME              7715 non-null   object
#  6   WORKTYPE                 7715 non-null   object
#  7   DESCRIPTION              1251 non-null   object
#  8   COMMENTS                 0 non-null      float64
#  9   ROUTENAME                7607 non-null   object
#  10  FROMSTREET               4926 non-null   object
#  11  TOSTREET                 4897 non-null   object
#  12  ROUTEID                  7607 non-null   object
#  13  FROMMEASURE              7607 non-null   float64
# ...

# %%
import os

files = os.listdir('.')

files = [file for file in files if 'csv' in file]

names = [file.replace('ProTrack_Project_', '').strip('.csv').lower() for file in files]

files
# Out:
# ['ProTrack_Project_Line.csv',
#  'ProTrack_Project_Initiation_Line.csv',
#  'ProTrack_Project_Point.csv',
#  'ProTrack_Project_Polygon.csv',
#  'ProTrack_Project_Initiation_Polygon.csv',
#  'ProTrack_Project_Initiation_Point.csv']

# %%
protrack = {f'{name}_df':pd.read_csv(f'./{file}') for name, file in zip(names, files)}

protrack['line_df']
# Out:
#       OBJECTID                                GLOBALID   PIID       PIIDBI  \
# 0      2435068  {5A820183-847E-4E08-852B-39845103986B}  10367  CFPPI170069
# 1      2435069  {03F87A41-0452-4E7A-9B33-E0B1484827DA}  10367  CFPPI170069
# 2      2435070  {2911705A-C600-413C-A40A-21D32B878F44}  10367  CFPPI170069
# 3      2435071  {0CE19905-AFB5-4B80-BEAF-230AAE5F6EB6}  10367  CFPPI170069
# 4      2435072  {E1552339-A8D5-443F-83EC-C025FE3D64AD}  10367  CFPPI170069
# ...        ...                                     ...    ...          ...
# 7352   2442229  {40839646-23C3-4B45-80F2-D8802C30C95D}  10428  CFPPI170129
# 7353   2442230  {086B2CE3-82F0-4CE5-91BB-F6873406F6FF}  10349  CFPPI170051
# 7354   2442231  {4E30F801-A53F-4F9F-BF8E-169D87D033EA}  10349  CFPPI170051
# 7355   2442232  {FCC65E58-EE3E-4E2E-ACC2-C749FA5EEF4B}  10349  CFPPI170051
# 7356   2442233  {187A15C1-D347-437B-9D90-35A5154C578D}  10349  CFPPI170051
#
# ...

# %%
protrack['point_df'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   X                        744 non-null    float64
#  1   Y                        744 non-null    float64
#  2   OBJECTID                 744 non-null    int64
#  3   GLOBALID                 744 non-null    object
#  4   PIID                     744 non-null    int64
#  5   PIIDBI                   744 non-null    object
#  6   PIUNIQUEID               744 non-null    int64
#  7   SOLICITATIONNUMBER       744 non-null    object
#  8   CONTRACTNUMBER           744 non-null    object
#  9   TASKORDERREQUESTNUMBER   0 non-null      float64
#  10  TASKORDERNUMBER          0 non-null      float64
#  11  WORKTYPE                 744 non-null    object
#  12  PROJECTNAME              744 non-null    object
#  13  PROJECTSTATUS            744 non-null    int64
# ...

# %%
import streamlit as st

points = protrack['point_df']

points.rename(columns={'X': 'lon', 'Y':'lat'}, inplace=True)

st.map(points)

# %%
points.DESCRIPTION.value_counts()
# Out:
# School location                                                 55
# School Location                                                 31
# Automated Traffic Enforcement Speed Camera (MPD) Location       30
# Crosswalk Re-Striping                                           23
# High Crash Location: Crosswalk Re-Striping                      21
#                                                                 ..
# KIPP DC - College Preparatory PCS                                1
# Friendship PCS - Armstrong Elementary                            1
# Anacostia High School                                            1
# Stop Bar Painting                                                1
# Automated Traffic Enforcement Speed Camera (MPD) Enforcement     1
# Name: DESCRIPTION, Length: 140, dtype: int64

# %%
protrack['polygon_df'].PROJECTNAME.value_counts()
# Out:
# Citywide Alley Restoration                                                                         871
# Oregon Avenue Watershed Green Streets Design                                                        30
# Green Alleys GI                                                                                      8
# MS4 Green Infrastructure Retrofits                                                                   4
# DC PLUG - Undergrounding of Power Line                                                               4
# Anacostia Freeway Bridges over Nicholson Street, S.E. [Bridges No.1001 (Ramp 6), 1002 (Ramp 4)]      3
# TOPS FY17  Enhancements                                                                              3
# Bike/Ped Improvements (Construction)                                                                 2
# Pennsylvania/Potomac Intersection Improvement                                                        2
# ...
